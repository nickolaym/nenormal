# %%
import normal

# %%
prg = [('a','b',True), ('c','d',False), ('e','f',True)]

# %%
normal.run_normal(prg, 'eeecccaaa')
# Out:
# 'eeedccbbb'

# %%
normal.run_normal(prg, 'eeecccaaa', (lambda s,p,d: print(s,p,d)))
# Out:
# eeecccaaa ('a', 'b', True) eeecccbaa
# eeecccbaa ('a', 'b', True) eeecccbba
# eeecccbba ('a', 'b', True) eeecccbbb
# eeecccbbb ('c', 'd', False) eeedccbbb
# 'eeedccbbb'
